# %% [markdown]
# ### Get the latest training material
# <div class="alert alert-box alert-warning">
# <b>IDT KRIA-SOM PYNQ-DPU Edge AI Training<br>
# Please run the below bash cell to get the latest version of IDT KRIA-SOM PYNQ-DPU Edge AI training material.
# </div>

# %%
# %%bash
# sudo systemctl restart reclone_training.service

# %%
# %%bash
# sudo systemctl status reclone_training.service || true
# Out:
# ○ reclone_training.service - Reclone Git Repository Service
#      Loaded: loaded (/etc/systemd/system/reclone_training.service; enabled; vendor preset: enabled)
#      Active: inactive (dead) since Mon 2024-07-22 21:39:35 UTC; 89ms ago
#     Process: 4717 ExecStart=/usr/local/bin/reclone_training.sh (code=exited, status=0/SUCCESS)
#    Main PID: 4717 (code=exited, status=0/SUCCESS)
#         CPU: 52.077s
#
# Jul 22 21:38:42 kria systemd[1]: Starting Reclone Git Repository Service...
# Jul 22 21:38:42 kria reclone_training.sh[4717]: Directory does not exist: /home/root/jupyter_notebooks/PYNQ_Bootcamp (IDT Trainings)
# Jul 22 21:38:42 kria reclone_training.sh[4717]: Cloning repository: https://github.com/Xilinx/PYNQ_Bootcamp.git
# Jul 22 21:38:42 kria reclone_training.sh[4718]: Cloning into '/home/root/jupyter_notebooks/PYNQ_Bootcamp (IDT Trainings)'...
# Jul 22 21:39:35 kria reclone_training.sh[4718]: [2.0K blob data]
# ...
