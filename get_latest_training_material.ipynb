# %% [markdown]
# ### Get the latest training material
# <div class="alert alert-box alert-warning">
# <b>PYNQ BootCamp 2023 Edition <br>
# Please run the below bash cell to get the latest version of the PYNQ Bootcamp materials
# </div>

# %%
# %%bash
# git stash
# git pull

# %%
# %%bash
# sudo systemctl stop local-setup.service
# sudo systemctl disable local-setup.service

# %%
# %%bash
# sudo pip3 install -e "/home/root/jupyter_notebooks/PYNQ_Bootcamp/genesis/client/pynq-sim"
# sudo pip3 install "/home/root/jupyter_notebooks/PYNQ_Bootcamp/bootcamp_sessions/PYNQ 504 - Board to Board Communication/pynq-p2p"
